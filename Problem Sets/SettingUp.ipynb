# %%
print("Hello Julia!")
# Out:
# Hello Julia!

# %%
import Pkg; Pkg.add("Plots")
# Out:
#     Updating registry at `C:\Users\sga68\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed GR_jll ─────────────────────── v0.73.27+0
#    Installed Libmount_jll ───────────────── v2.42.0+0
#    Installed JpegTurbo_jll ──────────────── v3.2.0+1
#    Installed Opus_jll ───────────────────── v1.6.1+0
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed LERC_jll ───────────────────── v4.1.0+0
#    Installed GR ─────────────────────────── v0.73.27
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed Measures ───────────────────── v0.3.3
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed Contour ────────────────────── v0.6.3
#    Installed RecipesPipeline ────────────── v0.6.12
# ...

# %%
using Plots
gr() # Secure ultra-fast, static Matplotlib-like plots (default)

# Generate data
x = range(0, 20, length=100)
y1 = sin.(x)
y2 = cos.(x)

# In Julia, columns represent separate data series
plot(x, [y1 y2], 
     label=["Sine" "Cosine"], 
     lw=2, 
     title="Matplotlib Style in Julia", 
     xlabel="X Axis", 
     ylabel="Y Axis")

# %%
using Plots
plotly() # Secure ultra-fast, static Matplotlib-like plots (default)

# Generate data
x = range(0, 10, length=100)
y1 = sin.(x)
y2 = cos.(x)

# In Julia, columns represent separate data series
plot(x, [y1 y2], 
     label=["Sine" "Cosine"], 
     lw=2, 
     title="Matplotlib Style in Julia", 
     xlabel="X Axis", 
     ylabel="Y Axis")
# Out:
# ┌ Warning: Failed to load integration with PlotlyBase & PlotlyKaleido.
# ...

# %%
import Pkg; Pkg.add("PlotlyJS")
# Out:
#    Resolving package versions...
#    Installed Pidfile ───────────────────── v1.3.0
#    Installed ConcurrentUtilities ───────── v2.6.0
#    Installed OpenSSL ───────────────────── v1.6.1
#    Installed JSON ──────────────────────── v0.21.4
#    Installed PlotlyKaleido ─────────────── v2.3.1
#    Installed PlotlyBase ────────────────── v0.8.23
#    Installed LoggingExtras ─────────────── v1.2.0
#    Installed SimpleBufferStream ────────── v1.2.0
#    Installed HTTP ──────────────────────── v1.11.0
#    Installed Blink ─────────────────────── v0.12.9
#    Installed WebIO ─────────────────────── v0.8.21
#    Installed TranscodingStreams ────────── v0.11.3
#    Installed AssetRegistry ─────────────── v0.1.1
#    Installed ExceptionUnwrapping ───────── v0.1.11
#    Installed Hiccup ────────────────────── v0.2.2
#    Installed MbedTLS ───────────────────── v1.1.10
#    Installed Lazy ──────────────────────── v0.15.1
#    Installed CodecZlib ─────────────────── v0.7.9
# ...

# %%
using Plots
plotly() # Activates your installed PlotlyJS backend
# plotlyjs()

# Generate data
x = range(0, 10, length=100)
y1 = sin.(x)
y2 = cos.(x)

# Combine into a single plot command
plot(x, [y1 y2], 
     label=["Sine" "Cosine"], 
     title="Interactive Plotly Graph",
     lw=2,
     xlabel="X Axis",
     ylabel="Y Axis",
     grid=true,               # Explicitly show background grid
     legend=:topright,        # Position the interactive legend
     )
# Out:
# <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>    <div id="id_7b16856a_4b54_4507_a135_f9475d9a09db" style="width:600px;height:400px;"></div>
#     <script>
#     ;(()=> {
#     function plots_jl_plotly_id_7b16856a_4b54_4507_a135_f9475d9a09db() {
#
#         Plotly.newPlot('id_7b16856a_4b54_4507_a135_f9475d9a09db', [
#     {
#         "colorbar": {
#             "len": 0.8657316272965879,
#             "title": "",
#             "x": 0.9934383202099738,
#             "y": 0.5086805555555556
#         },
#         "legendgroup": "Sine",
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "dash": "solid",
#             "shape": "linear",
#             "width": 2
#         },
#         "mode": "lines",
#         "name": "Sine",
#         "showlegend": true,
#         "type": "scatter",
#         "x": [
#             0.0,
#             0.10101010101010101,
#             0.20202020202020202,
#             0.30303030303030304,
# ...
